# %% [markdown]
# <a href="https://colab.research.google.com/github/Alonsobarrera27/POO/blob/main/Unidad%201/%20Introducci%C3%B3n_a_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
variable = input("Escribe tu nombre: ")
print("Tu nombre es: ", variable )

nom = input("¿Me puedes dar tu nombre por favor? ")
apellido = input("¿Me puedes dar tu apellido por favor? ")
print("Gracias.")
print("\nTu nombre es: " + nom + " " + apellido + ".")
print("\nTu nombre es: ", nom, apellido, ".")

# Marca error porque se debe convertir el tipo de dato.
x = input("Dame un numero para multiplicar ")
z = x * 5
print(z)

x = int(input("Dame un numero para multiplicar: "))
z = x * 5
print(z)

cateto_a = float(input("Inserta la longitud del primmer cateto: "))
cateto_b = float(input("Inserta la longitud del segundo cateto: "))
hipo = (cateto_a**2 + cateto_b**2)**.5
print("La longitud de la hipotenusa es: ", hipo )

a = 3000
b = 12500
if b > a:
  print("b es mayor que a")
else:
  print("a es mayor que b")

  print("Fin del if")

a = 30000
b = 12500
if b > a:
  print("b es mayor que a")
  print(b, "es mayor que", a)
else:
  print("a es mayor que b")
  print(a, "es mayor que", b)

a = 3000
b = 3000
if b > a:
  print("b es mayor que a")
  print("b vale=>", b)
elif a==b:
  print("a es igual que b")
  print("ay b valen =>", a)
else:
  print("a es mayor que b")
  print("a y b valen =>", a)
print("Fin del if")

# if y if... else en version corta o simplificada
# del lado izquierdo es cunado es verdadera la condicion

x = 50
y = 60

print("x es mayor que y") if (x > y) else print("y es mayor que x")

i = 1
while i <= 10:
  print(i)
  i += 1
print("fuera del while")

# BREAK
i = 1
while i <= 1000:
  print(i)
  if i == 10:
    print("Entra al if")
    break
  i += 1
print("fuera del while")

while(True):
  print(""" Selecciona una opcion
  1) Opcion 1
  2) Opcion 2
  3) Salir """)
  opcion = input("¿Cual es la opcion que deseas?: ")
  if opcion == "1":
    print("Seleccionaste la opcion 1 \n")
  elif opcion == "2":
    print("Seleccionaste la opcion 2\n")
  elif opcion == "3":
    print("Seleccionaste la Opcion Salir")
    break
  else:
    print("Opcion desconocida, vuelve a intentar\n")

# FOR
frutas = ["manzana", "platano", "cereza"]
for x in frutas:
  print(x)

palabra = "python"
for letra in palabra:
  print(letra)

for x in "banana":
  print(x)

for x in range(6):
  print(x)

for x in range(2, 6):
  print(x)

for x in range(2, 30, 3):
  print(x)

# FOR con else
for x in range(6):
  print(x)
else:
  print("Fin del for")

for x in range(6):
  if x == 3: break
  print(x)
else:
  print("Fin del for")

# FUNCIONES
def mi_funcion():
  print("Hola desde una función")

mi_funcion()

def funcion_con_argumentos(nombre):
  print("Hola", nombre)

funcion_con_argumentos("Juan")
funcion_con_argumentos("Maria")

def funcion_con_retorno(x):
  return 5 * x

print(funcion_con_retorno(3))
print(funcion_con_retorno(10))

def funcion_con_valor_por_defecto(pais = "México"):
  print("Yo soy de " + pais)

funcion_con_valor_por_defecto("España")
funcion_con_valor_por_defecto("Colombia")
funcion_con_valor_por_defecto()

# LISTAS
lista = ["manzana", "platano", "cereza"]
print(lista)
print(lista[1])

lista[1] = "uva"
print(lista)

for x in lista:
  print(x)

if "cereza" in lista:
  print("Sí, cereza está en la lista")

print(len(lista))

lista.append("naranja")
print(lista)

lista.insert(1, "sandia")
print(lista)

lista.remove("uva")
print(lista)

lista.pop()
print(lista)

del lista[0]
print(lista)

lista.clear()
print(lista)

# TUPLAS
tupla = ("manzana", "platano", "cereza")
print(tupla)
print(tupla[1])

# tupla[1] = "uva" # Esto marcaría error porque las tuplas son inmutables

# DICCIONARIOS
diccionario = {
  "marca": "Ford",
  "modelo": "Mustang",
  "año": 1964
}

print(diccionario)
print(diccionario["modelo"])

diccionario["año"] = 2020
print(diccionario)

for x in diccionario:
  print(x)

for x in diccionario:
  print(diccionario[x])

for x, y in diccionario.items():
  print(x, y)

if "modelo" in diccionario:
  print("Sí, 'modelo' está en el diccionario")

print(len(diccionario))

diccionario["color"] = "rojo"
print(diccionario)

diccionario.pop("modelo")
print(diccionario)

diccionario.popitem()
print(diccionario)

del diccionario["marca"]
print(diccionario)

diccionario.clear()
print(diccionario)

# CLASES Y OBJETOS
class Persona:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad

  def __str__(self):
    return f"{self.nombre} ({self.edad})"

p1 = Persona("Juan", 36)
print(p1)

class Persona2:
  def __init__(self, nombre, edad):
    self.nombre = nombre
    self.edad = edad

  def saludo(self):
    print("Hola, mi nombre es " + self.nombre)

p2 = Persona2("Maria", 25)
p2.saludo()
