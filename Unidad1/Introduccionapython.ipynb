# %% [markdown]
# <a href="https://colab.research.google.com/github/Alonsobarrera27/POO/blob/main/Unidad1/Introduccionapython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# **Programación Orientada a Objetos**
#
# ## **Unidad 1**
#
# **Introducción a la Programación Orientada a Objetos**
#
# ### Docente: José Gabriel Rodríguez Rivas
#
# ### Alumno: Jose Alonso Perez Barrera

# %%
variable = input("Escribe tu nombre: ")
print("Tu nombre es: ", variable )

nom = input("¿Me puedes dar tu nombre por favor? ")
apellido = input("¿Me puedes dar tu apellido por favor? ")
print("Gracias.")
print("\nTu nombre es: " + nom + " " + apellido + ".")
print("\nTu nombre es: ", nom, apellido, ".")

# Marca error porque se debe convertir el tipo de dato.
x = input("Dame un numero para multiplicar ")
z = x * 5
print(z)

x = int(input("Dame un numero para multiplicar: "))
z = x * 5
print(z)

cateto_a = float(input("Inserta la longitud del primmer cateto: "))
cateto_b = float(input("Inserta la longitud del segundo cateto: "))
hipo = (cateto_a*2 + cateto_b2)*.5
print("La longitud de la hipotenusa es: ", hipo )

a = 3000
b = 12500
if b > a:
  print("b es mayor que a")
else:
  print("a es mayor que b")

  print("Fin del if")

a = 30000
b = 12500
if b > a:
  print("b es mayor que a")
  print(b, "es mayor que", a)
else:
  print("a es mayor que b")
  print(a, "es mayor que", b)

a = 3
b = 5
if a == b:
  print("a y b son iguales")
else:
  if a > b:
    print("a es mayor")
  else:
    print("b es mayor")

calificacion = int(input("Introduce una calificacion: "))

if calificacion < 5:
  print("Insuficiente")
elif calificacion < 7:
  print("Suficiente")
elif calificacion < 9:
  print("Notable")
else:
  print("Sobresaliente")

a = 33
b = 200
if b > a:
  pass

x = 1
while x < 6:
  print(x)
  x += 1

x = 1
while x < 6:
  print(x)
  if x == 3:
    break
  x += 1

x = 0
while x < 6:
  x += 1
  if x == 3:
    continue
  print(x)

x = 1
while x < 6:
  print(x)
  x += 1
else:
  print("Ya no es menor que 6")

frutas = ["manzana", "platano", "cereza"]
for x in frutas:
  print(x)

for x in "platano":
  print(x)

frutas = ["manzana", "platano", "cereza"]
for x in frutas:
  print(x)
  if x == "platano":
    break

for x in frutas:
  if x == "platano":
    break
  print(x)

for x in frutas:
  if x == "platano":
    continue
  print(x)

for x in range(6):
  print(x)

for x in range(2, 6):
  print(x)

for x in range(2, 30, 3):
  print(x)

for x in range(6):
  print(x)
else:
  print("Fin del ciclo for")

adj = ["rojo", "grande", "sabroso"]
frutas = ["manzana", "platano", "cereza"]

for x in adj:
  for y in frutas:
    print(x, y)

def mi_funcion():
  print("Hola desde mi funcion")

mi_funcion()

def mi_funcion(nombre):
  print("Hola " + nombre)

mi_funcion("Alonso")
mi_funcion("Pedro")
mi_funcion("Juan")

def mi_funcion(nombre, apellido):
  print("Hola " + nombre + " " + apellido)

mi_funcion("Alonso", "Barrera")

def mi_funcion(*kids):
  print("El mas pequeño es " + kids[2])

mi_funcion("Emilio", "Alonso", "Andrea")

def mi_funcion(hijo3, hijo2, hijo1):
  print("El mas pequeño es " + hijo3)

mi_funcion(hijo1="Emilio", hijo2="Alonso", hijo3="Andrea")

def mi_funcion(**kid):
  print("Su apellido es " + kid["lname"])

mi_funcion(fname="Alonso", lname="Barrera")

def mi_funcion(pais="Mexico"):
  print("Yo soy de " + pais)

mi_funcion("Noruega")
mi_funcion("EUA")
mi_funcion()
mi_funcion("Brazil")

def mi_funcion(comida):
  for x in comida:
    print(x)

frutas = ["manzana", "platano", "cereza"]

mi_funcion(frutas)

def mi_funcion(x):
  return 5 * x

print(mi_funcion(3))
print(mi_funcion(5))
print(mi_funcion(9))
# Out:
# Escribe tu nombre: alonso
# Tu nombre es:  alonso
# ¿Me puedes dar tu nombre por favor? alonso
# ¿Me puedes dar tu apellido por favor? barrera
# Gracias.
#
# Tu nombre es: alonso barrera .
#
# Tu nombre es:  alonso barrera  .
# Dame un numero para multiplicar 50
# 5050505050
# Dame un numero para multiplicar: 1
# 5
